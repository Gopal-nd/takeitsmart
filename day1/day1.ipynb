# %%
from pandas import pd 
data = {
    'name':["gopal","Reddy","ND","superman"],
    'age':[20,23,99,None],
    'work':['remort','in person','user man','stap']
}
df = pd.DateFrame(data)
df
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from pandas import pd
#       2 data = {
#       3     'name':["gopal","Reddy","ND","superman"],
#       4     'age':[20,23,99,None],
#       5     'work':['remort','in person','user man','stap']
#       6 }
#       7 df = pd.DateFrame(data)
#
# ImportError: cannot import name 'pd' from 'pandas' (/home/gopal/takeitsmart/.venv/lib/python3.14/site-packages/pandas/__init__.py)
