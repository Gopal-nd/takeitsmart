# %% [raw]
# machine learning:
# it is a branch of artificial intelligence which is used to learn from the past information
# to predict the future values
#
# Types of ml:
#
# 1.supervised learning
# 2.unsupervised learning
# 3.Reinforcement

# %% [raw]
# 1.supervised learning:
# which has labelled data
#
# two types:
# 1.regression
# 2.classification

# %% [markdown]
# 1.regression:
# it shows the relationship between independent and dependent variable in a continuous format
#
# Linear regression:
# >>simple linear regression
# >>multi linear regression
#
#
# simple linear regression:
# if we have one independent varaible with continuous dependent variable then it is called as
# simple linear regression
#
# multi linear regression:
# if we have more than one independent variable with continuous dependent variable then it is called
# as multi linear regression

# %% [raw]
# 2.classification:
# output/target/dependent variable should be categorical

# %% [raw]
# Logistic regression
# support vector machine
# k nearest neighbors
# naive bayes
# decision tree
# random forest

# %% [raw]
# Logistic regression:
#
# it is a supervised machine learning algorithm which is used to solve all the classificattion problems
# it depends on the probability and ranges from 0 to 1
# it is also called as sigmoid function
# mainly used for binary classification where the output can be one of the two possible categories
# such as yes/no,true/false or 0/1
# multinomial classification---different categories i.e more than two cat/dog/lion/zebra etc
# ordinal classification---low/high/medium
#
# The formula for logistic regression is
# f(x)=1/1+e-x

# %% [raw]
# Assumptions of logistic regression:
# 1.independent observations:
#
# what ever the data point we are taking it should be independent of the other means there should be no
# correlation or dependence between the input samples
#
# 2.binary dependent variables:
# the dependent variable should be two value yes/no,0/1,t/f ,spam/not spam etc
#
# 3.linearity relationship:log odds,independent variables
#
# 4.no outliers:accuracy will be effected

# %% [raw]
# support vector machine:
#
# it is used to find the best boundary line/hyperplane/plane which helps to separate the classes in
# the dataset
#
# hyperplane:
# it is used to get the maximum margin between the classes based  on the support vectors

# %% [raw]
# margin:
#
# it is used to show the distance between hyperplane and the nearest data points

# %% [raw]
# support vectors:
# connecting with critical data points that will be closest to the boundary

# %% [raw]
# types of svm:
# 1.linear svm
# 2.non-linear svm

# %% [raw]
# popular kernals:
# linear kernals
# polynomial kernals
# rbf
# sigmoid kernel

# %% [raw]
# K nearest neighbors:
#
# it is one of supervised learning algorithm which works on both classification and regression
#
# how it works:
#
# choose the k value
#
# calculate the distance
#
# find the k nearest points
#
# predictions
#
# classfication---majority class
# regression---average value

# %% [raw]
# naive bayes:
# it is one of the supervised learning algorithm which is used to work on the probabilities
#
# use cases:
#
# spam detection
# sentiment analysis
# document categorization
# text classification

# %% [raw]
# bayes theorem  formula:
#
# p(a/b)=p(b/a).p(a)/p(b)

# %% [raw]
# types of bayes theorem:
#
# 1.gaussian naive bayes--------used for continuous numerical data
# 2.multinomial naive bayes------text classification tasks
# 3.bernoulli naive bayes-----word present in that or not

# %% [raw]
# decision tree:
# it is a supervised learning algorithm which is used to work on both classification and regression
#
# node---decision
# branch---outcome
# leaf---final prediction
#
# ASM(attribute selection measure)
#
# information gain
# gini index
#
# disadvantages:
# it cannot solve the overfitting

# %% [raw]
# Random forest:
# it is one of the supervised learning algorithm which works on both classification and regression
# it is also called as ensemble learning
# it is mainly used for overfitting problems
# it consists of multiple decision trees
# it also have bagging and boosting techniques

# %% [raw]
# boosting techniques:
# gradient boosting
# ada boost
# xg boosting

# %% [raw]
# Evaluation metrics for classification algorithms:
#
# confusion matrix:
#
# accuracy
# precision
# recall
# f-measure

# %% [raw]
# write mathematical implementation
